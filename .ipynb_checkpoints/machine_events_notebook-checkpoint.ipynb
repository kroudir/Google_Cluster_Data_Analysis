# %% [markdown]
# # Machine and machine events Analysis

# %% [markdown]
# ## Data Presentation
# In this part of the analysis, we will be using the machine events table
# ### Machine events
# Each machine is described by one or more records in the machine event table.
# #### Schema:
# 1. timestamp
# 2. machineID
# 3. eventtype
# 4. platformID
# 5. capacity:CPU
# 6. capacity:memory
# > There are three types of machine events:
# >- ADD (0): a machine became available to the cluster - all machines in the trace will
# have an ADD event.
# >- REMOVE (1): a machine was removed from the cluster. Removals can occur due to
# failures or maintenance.
# >- UPDATE (2): a machine available to the cluster had its available resources changed.

# %%
#Importing libraries used in this project
import sys, time

from pyspark import SparkContext
from pyspark.sql import SQLContext, Row, SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, TimestampType, FloatType, LongType
import pyspark.sql.functions as F


import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Setting the visualisations theme
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
#Create a spark context object with all the local available CPUs
sc = SparkContext("local[*]")
sc.setLogLevel("ERROR")

# %%
#Create a spark session
spark = spark = SparkSession.builder \
                .master("local") \
                .appName("machines-events-analysis") \
                .getOrCreate()

# %%
#Define a schema for the machine_events table
schema_machine_events = StructType([
    StructField("time", LongType(), True),
    StructField("machine_id", LongType(), True),
    StructField("event_type", IntegerType(), True),
    StructField("platform_id", StringType(), True),
    StructField("cpu_capacity", FloatType(), True),
    StructField("memory_capacity", FloatType(), True)])

# %%
#The path to the data file
path = "./clusterdata-2011-2/machine_events/part-00000-of-00001.csv.gz"

#Read the data into a SparkDataFrame
df_machine_event = spark.read.csv(path, header = False, schema = schema_machine_events)

# %% [markdown]
# ## Exploratory Data Analysis
# In this part we take check that the data is read correctly, and we check some statistics about this table.

# %%
#Visualize the first 10 rows to make sure data was read correctly.
df_machine_event.show(10)
# Out:
# +----+----------+----------+--------------------+------------+---------------+
# |time|machine_id|event_type|         platform_id|cpu_capacity|memory_capacity|
# +----+----------+----------+--------------------+------------+---------------+
# |   0|         5|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|         6|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|         7|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|        10|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|        13|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|        14|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|        19|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|        21|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|        23|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# |   0|        25|         0|HofLGzk1Or/8Ildj2...|         0.5|         0.2493|
# +----+----------+----------+--------------------+------------+---------------+
# only showing top 10 rows

# %%
#calcultate the number of entries
machine_events_nb_of_rows = df_machine_event.count()
print('We have {} in the machine Events Dataset'.format(machine_events_nb_of_rows))
# Out:
# We have 37780 in the machine Events Dataset

# %%
# Calculate the number of null values for each column
df_machine_event.select([F.count(F.when(F.col(c).isNull() | F.isnan(c), c)).alias(c) for c in df_machine_event.columns]).show()
# Out:
# +----+----------+----------+-----------+------------+---------------+
# |time|machine_id|event_type|platform_id|cpu_capacity|memory_capacity|
# +----+----------+----------+-----------+------------+---------------+
# |   0|         0|         0|          0|          32|             32|
# +----+----------+----------+-----------+------------+---------------+

# %% [markdown]
# - We notice that there is only 32 entries with missing CPU and Memory Capacity.

# %%
# Visialize the 32 rows with missing CPU capacity
df_machine_event.where(F.col('cpu_capacity').isNull()).show(32)
# Out:
# +-------------+----------+----------+--------------------+------------+---------------+
# |         time|machine_id|event_type|         platform_id|cpu_capacity|memory_capacity|
# +-------------+----------+----------+--------------------+------------+---------------+
# | 113019603442|6264344062|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 180634033944|6274355716|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 249144694693|6280638724|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 249253181592|6280643141|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 260626625747|6282149131|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 290874428583|6285257156|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 346499862525|6289355687|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 350980842744|6289704471|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 438565133335|6296268057|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 444959620528|6296865278|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 527346966412|6301942525|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 714679462134|6315250734|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 732632614150|6316827871|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 789566116463|6322213339|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 870980346660|6335261139|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# | 939696941180|6344084916|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1294687193277|6370662053|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1487853861396|6390664602|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1493952228106|6391270721|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1494263052154|6391293459|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1494869238511|6391374318|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1495242926077|6391421427|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1560366271607|6400066596|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1572599847250|6401302061|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1589834974914|6402941427|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1637257172170|6408086842|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1741601571162|6415978528|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1741638227211|6415979192|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |1989169943067|6437385645|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |2149027506418|6453653899|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |2161815884398|6455072430|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# |2181293543321|6457070948|         0|JQ1tVQBMHBAIISU1g...|        null|           null|
# +-------------+----------+----------+--------------------+------------+---------------+

# %% [markdown]
# - We see that the 32 entries with missing CPU capacity, are the same entries with missing memory capacity.

# %%
#Calculate the number of unique machine IDs
num_unique_machines = df_machine_event.select(F.countDistinct('machine_id')).collect()[0][0]
print('We have {} unique machine IDs in our dataset.'.format(num_unique_machines))
# Out:
# We have 12583 unique machine IDs in our dataset.

# %% [markdown]
# ## Data Analysis
# After getting familiair with out dataset, we will be interested in answering the following major questions in the coming part.
# 1. What is the distribution of the machines according to their CPU capacity/ Memory capacity?
# 2. What is the poucentage of computational time lost due to maintenance (a machine went offline and reconnected later)? What is the distribution of this time over CPU capacities/ Memory Capacities ?
# 3. What is the percentage of computational power lost due to maintenance (a machine went offline and reconnected later)? What is the distribution of this lost over CPU capacities/ Memory Capacities ?

# %% [markdown]
# ### 1. What is the distribution of the machines according to their CPU capacity/ Memory capacity?

# %%
#Create a dataframe without duplicates, where each row represent a machine
df_unique_machines = df_machine_event.dropDuplicates(['machine_id'])

# %%
#Test that the new dataframe size is equal to the number of unique machines already calculated
assert df_unique_machines.count() == num_unique_machines

# %%
#Create a dataframe with CPU capacity count and percentages
df_cpu_capacity_count = df_unique_machines.groupBy("cpu_capacity").count() \
    .withColumn("pourcentage", F.col("count")/ num_unique_machines * 100)

# %%
df_cpu_capacity_count.show()
# Out:
# +------------+-----+------------------+
# |cpu_capacity|count|       pourcentage|
# +------------+-----+------------------+
# |        0.25|  123|0.9775093379957085|
# |        null|   32|0.2543113724866884|
# |         0.5|11632| 92.44218389891124|
# |         1.0|  796| 6.325995390606373|
# +------------+-----+------------------+

# %%
#Create a dataframe with Memory capacity count and percentages
df_memory_capacity_count = df_unique_machines.groupBy("memory_capacity").count() \
    .withColumn("pourcentage", F.col("count")/ num_unique_machines * 100)

# %%
df_memory_capacity_count.show()
# Out:
# +---------------+-----+--------------------+
# |memory_capacity|count|         pourcentage|
# +---------------+-----+--------------------+
# |         0.2498|  123|  0.9775093379957085|
# |           null|   32|  0.2543113724866884|
# |            0.5|    3| 0.02384169117062704|
# |            1.0|  793|   6.302153699435746|
# |         0.2493| 3858|   30.66041484542637|
# |        0.03085|    5| 0.03973615195104506|
# |         0.4995| 6709|   53.31796868791226|
# |         0.9678|    4| 0.03178892156083605|
# |        0.06158|    1|0.007947230390209012|
# |         0.1241|   54| 0.42915044107128664|
# |          0.749| 1001|   7.955177620599222|
# +---------------+-----+--------------------+

# %%
#Convert the spark dataframe into a Pandas a dataframe to be able to use seaborn
pd_df_cpu_capacity_count = df_cpu_capacity_count.toPandas()
sns.barplot(x='cpu_capacity',y = 'pourcentage', data = pd_df_cpu_capacity_count);

# %%
#Convert the spark dataframe into a Pandas a dataframe to be able to use seaborn
pd_df_memory_capacity_count = df_memory_capacity_count.toPandas()
sns.barplot(x='memory_capacity',y = 'pourcentage', data = pd_df_memory_capacity_count);

# %% [markdown]
# - For CPU capacity, we observe that 92.5% of the machines have a medium CPU capacity (cpu_capacity = 0,5) compared to the high end machines, while the machines with highest computing capacity (cpu_capacity = 1) represent 6% of the totale, and the rest in between the machines we don't have information about and the slow machines (cpu_capacity = 0.25).
# - We notice also for memory that the 53% of the machines are with medium memory capacity compared the the high end machines, while machines with around 25% memory capacity compared to the high end machines represent 30.6%.
# - Over all, we notice that Google Cluster has a majority of medium capacity machines, with some high end machines and low end machines also.

# %% [markdown]
# ### 2. What is the poucentage of computational time lost due to maintenance (a machine went offline and reconnected later)? What is the distribution of this time over CPU capacities/ Memory Capacities ?

# %%
#Create a dataframe where each line is a unique machine and has events and time as a list as separate columns
df_machine_events_lists = df_machine_event.groupBy('machine_id') \
                    .agg(F.collect_list("event_type").alias('event_type_list') \
                         ,F.collect_list("time").alias('time_list') \
                         ,F.mean('cpu_capacity').alias('cpu_capacity') \
                         ,F.mean('memory_capacity').alias('memory_capacity'))

df_machine_events_lists.show(5)
# Out:
# +----------+------------------+--------------------+------------+-------------------+
# |machine_id|   event_type_list|           time_list|cpu_capacity|    memory_capacity|
# +----------+------------------+--------------------+------------+-------------------+
# |        26|[1, 0, 2, 2, 2, 0]|[611893094118, 70...|         0.5| 0.2493000030517578|
# |    381364|               [0]|                 [0]|         0.5|0.49950000643730164|
# |    418690|               [0]|                 [0]|         0.5|0.49950000643730164|
# |    672517|               [0]|                 [0]|         0.5|0.49950000643730164|
# |    903236|               [0]|                 [0]|         0.5|0.49950000643730164|
# +----------+------------------+--------------------+------------+-------------------+
# only showing top 5 rows

# %%
#check that the dataframe has all the machines
assert df_machine_events_lists.count() == num_unique_machines

# %%
#Get the end time, which is the maximum in the time column is the original dataset
time_end = df_machine_event.agg({"time": "max"}).collect()[0][0]
print('The end time is {}'.format(time_end))
# Out:
# The end time is 2506135493517

# %%
def calculate_down_time(event_type_list, time_list,max_active_time):
    """
    Calculate the down time of a machine
    Arguments : 
        event_type_list : a list of the events
        time_list : a list of the timestamps of occurrence of each event
    """
    
    full_down_time = 0
    
    #Loop over the list of events
    for i in range(len(event_type_list) - 1):
        if event_type_list[i] == 1 and event_type_list[i + 1] == 0: #if current event is DELETE and the coming event is ADD
            down_time = time_list[i + 1] - time_list[i] #Calculate the down time
            full_down_time += down_time 
    
    #if the last event is DELETE
    if event_type_list[len(event_type_list) - 1] == 1:
        down_time = max_active_time - time_list[len(event_type_list) - 1] #Calculate the down time
        full_down_time += down_time 
    
    #if the first event is ADD
    if event_type_list[0] == 0:
        down_time = time_list[0] #Calculate the down time
        full_down_time += down_time 
    
    return full_down_time

#Create a spark UDF to calculate the down time
calculate_down_time_udf = F.udf(lambda event_type_list, time_list, max_active_time: calculate_down_time(event_type_list,time_list,max_active_time), LongType())

# %%
df_machine_events_lists = df_machine_events_lists.withColumn('max_active_time', F.lit(time_end))
df_machine_events_lists.show(10)
# Out:
# +----------+--------------------+--------------------+------------+-------------------+---------------+
# |machine_id|     event_type_list|           time_list|cpu_capacity|    memory_capacity|max_active_time|
# +----------+--------------------+--------------------+------------+-------------------+---------------+
# |        26|  [1, 0, 2, 2, 2, 0]|[611893094118, 70...|         0.5| 0.2493000030517578|  2506135493517|
# |    381364|                 [0]|                 [0]|         0.5|0.49950000643730164|  2506135493517|
# |    418690|                 [0]|                 [0]|         0.5|0.49950000643730164|  2506135493517|
# |    672517|                 [0]|                 [0]|         0.5|0.49950000643730164|  2506135493517|
# |    903236|                 [0]|                 [0]|         0.5|0.49950000643730164|  2506135493517|
# |   1093605|           [0, 1, 0]|[0, 1965942760059...|         0.5| 0.2493000030517578|  2506135493517|
# |   1268612|                 [0]|                 [0]|         0.5|0.12409999966621399|  2506135493517|
# |   1271879|[0, 1, 0, 1, 0, 1...|[0, 1227464159780...|         0.5|0.49950000643730164|  2506135493517|
# |   1272595|           [0, 1, 0]|[0, 1691697467175...|         0.5|0.49950000643730164|  2506135493517|
# |   1273026|                 [0]|                 [0]|         0.5|0.49950000643730164|  2506135493517|
# +----------+--------------------+--------------------+------------+-------------------+---------------+
# only showing top 10 rows

# %%
#Create a dataframe with a new column down_time that has the down time of the specefied machine.
df_machine_events_down_time = df_machine_events_lists.select('machine_id','cpu_capacity',
                                                    'memory_capacity','event_type_list','time_list','max_active_time',
                                        calculate_down_time_udf('event_type_list','time_list','max_active_time').alias('down_time'))

df_machine_events_down_time.show()
# Out:
# +----------+------------+-------------------+--------------------+--------------------+---------------+-----------+
# |machine_id|cpu_capacity|    memory_capacity|     event_type_list|           time_list|max_active_time|  down_time|
# +----------+------------+-------------------+--------------------+--------------------+---------------+-----------+
# |        26|         0.5| 0.2493000030517578|  [1, 0, 2, 2, 2, 0]|[611893094118, 70...|  2506135493517|88666880740|
# |    381364|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |    418690|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |    672517|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |    903236|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   1093605|         0.5| 0.2493000030517578|           [0, 1, 0]|[0, 1965942760059...|  2506135493517|    8891208|
# |   1268612|         0.5|0.12409999966621399|                 [0]|                 [0]|  2506135493517|          0|
# |   1271879|         0.5|0.49950000643730164|[0, 1, 0, 1, 0, 1...|[0, 1227464159780...|  2506135493517| 7933456256|
# |   1272595|         0.5|0.49950000643730164|           [0, 1, 0]|[0, 1691697467175...|  2506135493517|  298220949|
# |   1273026|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   1273307|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   1331701|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   1338600|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   1697839|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   3936060|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   6565013|         0.5|0.49950000643730164|     [0, 1, 0, 1, 0]|[0, 1769325761222...|  2506135493517| 1224533202|
# |   6569659|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   6641557|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   6648751|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# |   7352912|         0.5|0.49950000643730164|                 [0]|                 [0]|  2506135493517|          0|
# +----------+------------+-------------------+--------------------+--------------------+---------------+-----------+
# only showing top 20 rows

# %%
df_machine_events_down_active_time = df_machine_events_down_time.select('machine_id',
                                        'cpu_capacity','memory_capacity', 'down_time','max_active_time') \
                                    .withColumn('real_active_time', F.col('max_active_time') - F.col('down_time')) \
                                    .withColumn('poucentage_down_time', F.col('down_time') / F.col('max_active_time') * 100)

df_machine_events_down_active_time.show(10)
# Out:
# +----------+------------+-------------------+-----------+---------------+----------------+--------------------+
# |machine_id|cpu_capacity|    memory_capacity|  down_time|max_active_time|real_active_time|poucentage_down_time|
# +----------+------------+-------------------+-----------+---------------+----------------+--------------------+
# |        26|         0.5| 0.2493000030517578|88666880740|  2506135493517|   2417468612777|  3.5379922980767815|
# |    381364|         0.5|0.49950000643730164|          0|  2506135493517|   2506135493517|                 0.0|
# |    418690|         0.5|0.49950000643730164|          0|  2506135493517|   2506135493517|                 0.0|
# |    672517|         0.5|0.49950000643730164|          0|  2506135493517|   2506135493517|                 0.0|
# |    903236|         0.5|0.49950000643730164|          0|  2506135493517|   2506135493517|                 0.0|
# |   1093605|         0.5| 0.2493000030517578|    8891208|  2506135493517|   2506126602309|3.547776256710874E-4|
# |   1268612|         0.5|0.12409999966621399|          0|  2506135493517|   2506135493517|                 0.0|
# |   1271879|         0.5|0.49950000643730164| 7933456256|  2506135493517|   2498202037261| 0.31656134620505044|
# |   1272595|         0.5|0.49950000643730164|  298220949|  2506135493517|   2505837272568|0.011899633909317883|
# |   1273026|         0.5|0.49950000643730164|          0|  2506135493517|   2506135493517|                 0.0|
# +----------+------------+-------------------+-----------+---------------+----------------+--------------------+
# only showing top 10 rows

# %%
#show the top 20 machines in term of down time
df_machine_events_down_active_time.sort(F.desc('poucentage_down_time')).show(20)
# Out:
, 1248246372784, 1257033723120, 1257041384181, 1274249123978, 1274257420815, 1281633275386, 1281645022371, 1289825116439, 1289831353793, 1297831017311, 1297837646479, 1306059658631, 1306066917948, 1313781627893, 1313789006795, 1322207198316, 1322213130192, 1330708032043, 1330714139142, 1338397205522, 1338403481491, 1346271976094, 1346279482236, 1354055146798, 1354060841359, 1361642471161, 1361648472504, 1369881009251, 1369887076587, 1377399152870, 1377406376949, 1386058624198, 1386064778681, 1394164576645, 1394170250389, 1409659480670, 1409664803824, 1418629227810, 1418634538013, 1427509537487, 1427516259783, 1435207555019, 1435215205652, 1443152626165, 1443159421418, 1451724206400, 1451729939873, 1459807572594, 1459814053711, 1468906594464, 1468913366394, 1477759809741, 1477765841039, 1485761037314, 1485766849274, 1493120230184, 1493126924432, 1500842183617, 1500849716017, 1508210454371, 1508217380217, 1516919686928, 1516926168067, 1525738985269, 1525746425622, 1534239386361, 1534245785206, 1542500155508, 1542508103470, 1548515956848, 1548522195834, 1557359276655, 1557376217519, 1566142958111, 1566157702915, 1573738120919, 1573744743594, ...

# %%
df_machine_events_down_time.where(F.col('machine_id') == 418549).collect()
# Out:
# [Row(machine_id=418549, cpu_capacity=0.5, memory_capacity=0.49950000643730164, event_type_list=[1, 0, 1, 0], time_list=[1127455171516, 1128454954349, 2116471557944, 0], max_active_time=2506135493517, down_time=-2115471775111)]

# %% [markdown]
# The machine has 0 as the time of the last event_type, which doesn't make sense, this can be related to a anomaly while doing the data collection. Since it is only on one machine, will ignore it for the time being.

# %%
#Delete the machine of ID 418549
df_machine_events_down_active_time = df_machine_events_down_active_time.where(F.col('machine_id') != 418549)
df_machine_events_down_active_time.sort(F.asc('poucentage_down_time')).show(5)
# Out:
# +----------+------------+-------------------+---------+---------------+----------------+--------------------+
# |machine_id|cpu_capacity|    memory_capacity|down_time|max_active_time|real_active_time|poucentage_down_time|
# +----------+------------+-------------------+---------+---------------+----------------+--------------------+
# |   1268958|         0.5|0.49950000643730164|        0|  2506135493517|   2506135493517|                 0.0|
# |   2851625|         0.5| 0.2493000030517578|        0|  2506135493517|   2506135493517|                 0.0|
# |   1270312|         0.5|0.49950000643730164|        0|  2506135493517|   2506135493517|                 0.0|
# |    765598|         0.5|0.49950000643730164|        0|  2506135493517|   2506135493517|                 0.0|
# |   1272497|         0.5|0.49950000643730164|        0|  2506135493517|   2506135493517|                 0.0|
# +----------+------------+-------------------+---------+---------------+----------------+--------------------+
# only showing top 5 rows

# %%
#Create a pandas dataFrame to use to create visualisations
pd_df_machine_events_down_active_time = df_machine_events_down_active_time.toPandas()

# %%
df_machine_events_down_active_time.agg(F.mean('poucentage_down_time')).collect()[0][0]
# Out:
# 0.8514609721235055

# %%
df_machine_events_down_active_time.agg(F.sum('down_time') /F.sum('max_active_time') * 100).collect()[0][0]
# Out:
# 0.8514609721235056

# %%
sns.violinplot(y="poucentage_down_time", data=pd_df_machine_events_down_active_time);

# %%
sns.violinplot(x="cpu_capacity", y="poucentage_down_time", data=pd_df_machine_events_down_active_time);

# %%
sns.boxplot(x="memory_capacity", y="poucentage_down_time", data=pd_df_machine_events_down_active_time);

# %% [markdown]
# - The visualisations aren't really clear since there is a lot of anomalies, so we will get rid of the anomalies and plot again.

# %%
#Delete the entries with poucentage_down_time > 20%
df_machine_events_down_active_time_no_anomaly = df_machine_events_down_active_time.where(F.col('poucentage_down_time') < 20.0)
print('We kept {0:0.2f} of the data'.format(df_machine_events_down_active_time_no_anomaly.count() 
                                      / df_machine_events_down_active_time.count() * 100))
# Out:
# We kept 99.18 of the data

# %%
#convert dataframe to pandas
pd_df_machine_events_down_active_time_no_anomaly = df_machine_events_down_active_time_no_anomaly.toPandas()

# %%
_, axes = plt.subplots(1, 2, sharey=False)

sns.violinplot(y="poucentage_down_time", data=pd_df_machine_events_down_active_time, ax=axes[0]);
sns.violinplot(y="poucentage_down_time", data=pd_df_machine_events_down_active_time_no_anomaly, ax=axes[1]);

# %%
_, axes = plt.subplots(1, 2, sharey=False)

sns.violinplot(x="cpu_capacity", y="poucentage_down_time", data=pd_df_machine_events_down_active_time,ax=axes[0]);
sns.violinplot(x="cpu_capacity", y="poucentage_down_time", data=pd_df_machine_events_down_active_time_no_anomaly, ax=axes[1]);

# %%
_, axes = plt.subplots(1, 2, sharey=False)

ax0 = sns.boxplot(x="memory_capacity", y="poucentage_down_time", 
                  data=pd_df_machine_events_down_active_time,ax=axes[0]);
plt.xticks(rotation=90);

ax1 =sns.boxplot(x="memory_capacity", y="poucentage_down_time", 
                 data=pd_df_machine_events_down_active_time_no_anomaly, ax=axes[1]);
plt.xticks(rotation=90);

# %% [markdown]
# ### 3. What is the percentage of computational power lost due to maintenance (a machine went offline and reconnected later)? What is the distribution of this lost over CPU capacities/ Memory Capacities ?

# %%
total_capacity = df_machine_events_down_active_time.agg(F.sum('cpu_capacity')).collect()[0][0]
print('The total calculation capacity in our cluster is : {}'.format(total_capacity))
# Out:
# The total calculation capacity in our cluster is : 6658.5

# %%
#comment
df_machine_events_lost_power_no_anomaly = \
        df_machine_events_down_active_time \
        .withColumn('lost_power',
                    F.col('down_time') * F.col('cpu_capacity') * 100 / time_end)
df_machine_events_lost_power_no_anomaly.select('machine_id','down_time','poucentage_down_time','cpu_capacity','lost_power').show(10)
# Out:
# +----------+-----------+--------------------+------------+--------------------+
# |machine_id|  down_time|poucentage_down_time|cpu_capacity|          lost_power|
# +----------+-----------+--------------------+------------+--------------------+
# |        26|88666880740|  3.5379922980767815|         0.5|  1.7689961490383908|
# |    381364|          0|                 0.0|         0.5|                 0.0|
# |    418690|          0|                 0.0|         0.5|                 0.0|
# |    672517|          0|                 0.0|         0.5|                 0.0|
# |    903236|          0|                 0.0|         0.5|                 0.0|
# |   1093605|    8891208|3.547776256710874E-4|         0.5|1.773888128355436...|
# |   1268612|          0|                 0.0|         0.5|                 0.0|
# |   1271879| 7933456256| 0.31656134620505044|         0.5| 0.15828067310252522|
# |   1272595|  298220949|0.011899633909317883|         0.5|0.005949816954658...|
# |   1273026|          0|                 0.0|         0.5|                 0.0|
# +----------+-----------+--------------------+------------+--------------------+
# only showing top 10 rows

# %%
df_machine_events_lost_power_no_anomaly.agg(F.mean('lost_power')).collect()[0][0]
# Out:
# 0.4438789678202388

# %%
df_machine_events_lost_power_no_anomaly.select('machine_id','down_time','poucentage_down_time','cpu_capacity','lost_power_percentage').sort(F.desc('lost_power_percentage')).show(10)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-70-a39707668e68> in <module>
# ----> 1 df_machine_events_lost_power_no_anomaly.select('machine_id','down_time','poucentage_down_time','cpu_capacity','lost_power_percentage').sort(F.desc('lost_power_percentage')).show(10)
#
# /usr/local/spark/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1419         [Row(name=u'Alice', age=12), Row(name=u'Bob', age=15)]
#    1420         """
# -> 1421         jdf = self._jdf.select(self._jcols(*cols))
#    1422         return DataFrame(jdf, self.sql_ctx)
#    1423
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     132                 # Hide where the exception came from that shows a non-Pythonic
#     133                 # JVM exception message.
# --> 134                 raise_from(converted)
#     135             else:
#     136                 raise
#
# /usr/local/spark/python/pyspark/sql/utils.py in raise_from(e)
#
# AnalysisException: cannot resolve '`lost_power_percentage`' given input columns: [cpu_capacity, down_time, lost_power, machine_id, max_active_time, memory_capacity, poucentage_down_time, real_active_time];;
# 'Project [machine_id#1L, down_time#788L, poucentage_down_time#866, cpu_capacity#223, 'lost_power_percentage]
# +- Project [machine_id#1L, cpu_capacity#223, memory_capacity#225, down_time#788L, max_active_time#732L, real_active_time#859L, poucentage_down_time#866, (((cast(down_time#788L as double) * cpu_capacity#223) * cast(100 as double)) / cast(2506135493517 as double)) AS lost_power#31594]
#    +- Filter NOT (machine_id#1L = cast(418549 as bigint))
#       +- Project [machine_id#1L, cpu_capacity#223, memory_capacity#225, down_time#788L, max_active_time#732L, real_active_time#859L, ((cast(down_time#788L as double) / cast(max_active_time#732L as double)) * cast(100 as double)) AS poucentage_down_time#866]
#          +- Project [machine_id#1L, cpu_capacity#223, memory_capacity#225, down_time#788L, max_active_time#732L, (max_active_time#732L - down_time#788L) AS real_active_time#859L]
#             +- Project [machine_id#1L, cpu_capacity#223, memory_capacity#225, down_time#788L, max_active_time#732L]
#                +- Project [machine_id#1L, cpu_capacity#223, memory_capacity#225, event_type_list#219, time_list#221, max_active_time#732L, <lambda>(event_type_list#219, time_list#221, max_active_time#732L) AS down_time#788L]
#                   +- Project [machine_id#1L, event_type_list#219, time_list#221, cpu_capacity#223, memory_capacity#225, 2506135493517 AS max_active_time#732L]
#                      +- Project [machine_id#1L, event_type_list#219, time_list#221, cpu_capacity#223, memory_capacity#225, 2506135493517 AS max_active_time#615L]
#                         +- Project [machine_id#1L, event_type_list#219, time_list#221, cpu_capacity#223, memory_capacity#225, 2506135493517 AS max_active_time#498L]
#                            +- Project [machine_id#1L, event_type_list#219, time_list#221, cpu_capacity#223, memory_capacity#225, 2506135493517 AS max_active_time#443L]
#                               +- Project [machine_id#1L, event_type_list#219, time_list#221, cpu_capacity#223, memory_capacity#225, 2506135493517 AS max_active_time#374L]
#                                  +- Aggregate [machine_id#1L], [machine_id#1L, collect_list(event_type#2, 0, 0) AS event_type_list#219, collect_list(time#0L, 0, 0) AS time_list#221, avg(cast(cpu_capacity#4 as double)) AS cpu_capacity#223, avg(cast(memory_capacity#5 as double)) AS memory_capacity#225]
#                                     +- Relation[time#0L,machine_id#1L,event_type#2,platform_id#3,cpu_capacity#4,memory_capacity#5] csv
